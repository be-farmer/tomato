# %%
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np

# %%
# Load data
data = pd.read_csv("../sample/2023_smartFarm_AI_hackathon_dataset.csv")

# %%
# Date conversion
data['date'] = pd.to_datetime(data['date'])

# %%
# Selecting columns
# selected_columns = ['outtrn_cumsum', 'HeatingEnergyUsage_cumsum', 'avg_sir', 'avg_atmospheric_pressure', 
#                     'avg_rhm', 'avg_windspeed', 'sum_rainfall', 'sum_insolation', 'avg_ground_temperature', 
#                     'plantingDate', 'frming_length', 'frmingWidth']

# data = data[selected_columns]

# Fill missing values
# data.fillna(method='ffill', inplace=True)

# Splitting data
train_data, test_data = train_test_split(data, test_size=0.2, random_state=42)
train_data.shape, test_data.shape
# Out:
# ((67872, 47), (16968, 47))

# %%
from pycaret.regression import *

# Initialize PyCaret environment
regression_setup = setup(data=data, target='outtrn_cumsum', 
                         train_size=0.8, verbose=False, 
                         remove_multicollinearity=True, multicollinearity_threshold=0.9, 
                         normalize=True, transformation=True, 
                         categorical_features=['frmDist'])

# %%
compare_models()
# Out:
# <style type="text/css">
# #T_489b7 th {
#   text-align: left;
# }
# ...

# %%
from pycaret.regression import *

# Initialize PyCaret environment
regression_setup_heat = setup(data=data, target='HeatingEnergyUsage_cumsum', 
                         train_size=0.8, verbose=False, 
                         remove_multicollinearity=True, multicollinearity_threshold=0.9, 
                         normalize=True, transformation=True, 
                         categorical_features=['frmDist'])

# %%
compare_models()
# Out:
# <style type="text/css">
# #T_2d2f7 th {
#   text-align: left;
# }
# ...
